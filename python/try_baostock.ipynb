# %%
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import baostock as bs
from datetime import datetime, timedelta
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
lg = bs.login()
# Out:
# login success!

# %%
datetime.now().strftime('%Y-%M-%d')
# Out:
# '2018-10-03'

# %%
dt = datetime(2016,7,18, 2, 55)
print(dt - timedelta(days=5))
# Out:
# 2016-07-13 02:55:00

# %%
rs_days = bs.query_history_k_data("sh.600036",
    "date,open,close,high,low,volume,amount,turn",
    start_date='2018-07-28', end_date='2018-09-28',frequency="d")

# %%
data_days = rs_days.get_data()
data_days['ma3'] = np.round(pd.Series.rolling(data_days['close'], 3).mean(), 2)
data_days['ma5'] = np.round(pd.Series.rolling(data_days['close'], 5).mean(), 2)
data_days['ma3-ma5'] = data_days['ma3'] - data_days['ma5']

# %%
data_days[['ma3', 'ma5']].plot(marker='o',xticks=[40, 41, 42, 43],xlim=(40,44))

# %%
data_days['ma3-ma5'].plot(subplots=True, marker='o',xticks=[40, 41, 42, 43],xlim=(40,44))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x110fbd748>],
#       dtype=object)

# %%
# 策略： 以当日收盘价计算，如果ma3_price > ma5_price，则次日以开盘价买入；如果ma3_price < ma5_price，则次日以开盘价卖出。
# 以2016-09-28日起始，从2016-10-11开始计算，每次只交易100股，按5元一次计算手续费。
signals=[]
isBuy=False
dateBuy=''
priceBuy=0
isSell=False
dateSell=''
priceSell=0
profitTotal=0
feeTotal=0
assets=0
i=0
for index in data_days['ma5'].index:
    signal = 1 # 买入
    if data_days['ma3'][index] > data_days['ma5'][index]:
        signal = 1
    else:
        signal = 0
    
    signals.append(signal)
    #print("%s, open %s, close %s, %s" % (data_days['date'][index], data_days['open'][index], data_days['close'][index], signal))
    if i > 3:
        # if isBuy:
        #     print('buy')
        #     
        # if isSell:
        #     prict('sell')
            
        if signals[i] > signals[i-1]:
            isBuy = True
            feeTotal += 5
            dateBuy = data_days['date'][index]
            priceBuy = float(data_days['close'][index])
            assets = priceBuy * 100
            #print(index, 'buy price %s' % priceBuy)
        
        if signals[i] < signals[i-1]:
            isSell = True
            feeTotal += 5
            dateSell = data_days['date'][index]
            priceSell = float(data_days['close'][index])
            profit = priceSell*100 - assets - 10
            profitTotal += profit
            assets = 0
            print("buy price %.2f on %s, sell price %.2f on %s, profit %d, total profit %d" % 
                  (priceBuy, dateBuy, priceSell, dateSell ,profit, profitTotal))

    i+=1
# Out:
# buy price 18.33 on 2016-10-11, sell price 18.10 on 2016-10-14, profit -32, total profit -32
# buy price 18.31 on 2016-10-24, sell price 17.81 on 2016-10-27, profit -60, total profit -92
# buy price 17.98 on 2016-11-01, sell price 17.91 on 2016-11-04, profit -17, total profit -109
# buy price 17.99 on 2016-11-08, sell price 17.89 on 2016-11-09, profit -19, total profit -129
# buy price 18.00 on 2016-11-10, sell price 18.10 on 2016-11-18, profit 0, total profit -129
# buy price 18.34 on 2016-11-21, sell price 18.55 on 2016-11-30, profit 11, total profit -118
# buy price 18.60 on 2016-12-06, sell price 18.82 on 2016-12-14, profit 11, total profit -106
# buy price 17.62 on 2016-12-28, sell price 17.49 on 2016-12-29, profit -23, total profit -129
# buy price 18.02 on 2017-01-04, sell price 17.94 on 2017-01-09, profit -17, total profit -147
# buy price 18.00 on 2017-01-12, sell price 18.62 on 2017-02-06, profit 52, total profit -95
# buy price 18.90 on 2017-02-10, sell price 19.43 on 2017-02-24, profit 43, total profit -52
# buy price 19.44 on 2017-02-28, sell price 19.34 on 2017-03-01, profit -20, total profit -72
# buy price 19.29 on 2017-03-08, sell price 18.91 on 2017-03-10, profit -48, total profit -120
# buy price 19.01 on 2017-03-15, sell price 18.81 on 2017-03-17, profit -30, total profit -150
# buy price 19.10 on 2017-03-27, sell price 18.89 on 2017-04-07, profit -31, total profit -182
# buy price 19.05 on 2017-04-12, sell price 18.82 on 2017-04-14, profit -33, total profit -215
# buy price 18.91 on 2017-04-24, sell price 19.01 on 2017-05-02, profit 0, total profit -214
# buy price 19.02 on 2017-05-10, sell price 20.25 on 2017-05-18, profit 113, total profit -101
# buy price 20.89 on 2017-05-22, sell price 22.16 on 2017-06-02, profit 117, total profit 15
# buy price 22.74 on 2017-06-08, sell price 21.30 on 2017-06-14, profit -154, total profit -138
# buy price 21.31 on 2017-06-21, sell price 23.52 on 2017-07-03, profit 211, total profit 72
# buy price 23.26 on 2017-07-07, sell price 24.08 on 2017-07-11, profit 72, total profit 144
# buy price 24.34 on 2017-07-12, sell price 25.22 on 2017-07-19, profit 78, total profit 222
# buy price 24.74 on 2017-07-21, sell price 25.98 on 2017-08-07, profit 114, total profit 336
# buy price 25.54 on 2017-08-09, sell price 25.14 on 2017-08-10, profit -50, total profit 286
# buy price 25.17 on 2017-08-16, sell price 25.30 on 2017-08-21, profit 3, total profit 289
# buy price 25.89 on 2017-08-22, sell price 26.75 on 2017-08-31, profit 76, total profit 365
# buy price 27.34 on 2017-09-05, sell price 26.35 on 2017-09-07, profit -109, total profit 256
# buy price 25.89 on 2017-09-20, sell price 25.95 on 2017-09-22, profit -4, total profit 252
# buy price 26.08 on 2017-10-09, sell price 26.50 on 2017-10-23, profit 32, total profit 284
# buy price 26.55 on 2017-10-26, sell price 26.90 on 2017-11-01, profit 25, total profit 309
# buy price 27.07 on 2017-11-09, sell price 30.09 on 2017-11-24, profit 292, total profit 601
# buy price 28.93 on 2017-12-06, sell price 28.52 on 2017-12-08, profit -51, total profit 550
# buy price 28.60 on 2017-12-13, sell price 28.63 on 2017-12-14, profit -7, total profit 543
# buy price 29.47 on 2017-12-20, sell price 29.29 on 2017-12-25, profit -28, total profit 515
# buy price 29.97 on 2018-01-03, sell price 29.47 on 2018-01-08, profit -60, total profit 455
# buy price 30.53 on 2018-01-10, sell price 32.98 on 2018-01-29, profit 234, total profit 689
# buy price 34.45 on 2018-02-01, sell price 32.39 on 2018-02-07, profit -216, total profit 473
# buy price 31.50 on 2018-02-22, sell price 30.87 on 2018-02-27, profit -73, total profit 400
# buy price 30.77 on 2018-03-07, sell price 30.39 on 2018-03-14, profit -48, total profit 352
# buy price 30.99 on 2018-03-20, sell price 29.11 on 2018-03-26, profit -198, total profit 154
# buy price 29.09 on 2018-03-30, sell price 28.81 on 2018-04-03, profit -38, total profit 116
# buy price 30.29 on 2018-04-10, sell price 28.11 on 2018-04-16, profit -228, total profit -111
# buy price 28.21 on 2018-04-20, sell price 28.93 on 2018-05-07, profit 62, total profit -49
# buy price 29.75 on 2018-05-09, sell price 29.80 on 2018-05-17, profit -5, total profit -54
# buy price 29.82 on 2018-05-22, sell price 29.61 on 2018-05-23, profit -31, total profit -85
# buy price 29.25 on 2018-06-04, sell price 28.20 on 2018-06-08, profit -115, total profit -200
# buy price 28.71 on 2018-06-13, sell price 28.65 on 2018-06-21, profit -16, total profit -216
# buy price 25.84 on 2018-07-06, sell price 26.23 on 2018-07-13, profit 29, total profit -187
# buy price 27.38 on 2018-07-20, sell price 27.18 on 2018-08-02, profit -30, total profit -217
# buy price 28.48 on 2018-08-07, sell price 27.51 on 2018-08-14, profit -107, total profit -324
# buy price 27.10 on 2018-08-21, sell price 28.29 on 2018-08-31, profit 109, total profit -215
# buy price 27.40 on 2018-09-11, sell price 27.40 on 2018-09-12, profit -10, total profit -225

# %%
date='2016-07-18'
rs_5min = bs.query_history_k_data("sh.600036",
    "date,time,open,close,high,low,volume,amount",
    start_date=date, end_date=date,frequency="5")
data_5min = rs_5min.get_data()
data_5min['open'] = pd.to_numeric(data_5min['open'], downcast='float')

# %%
data_5min['time']
# Out:
# 0     20160718093500000
# 1     20160718094000000
# 2     20160718094500000
# 3     20160718095000000
# 4     20160718095500000
# 5     20160718100000000
# 6     20160718100500000
# 7     20160718101000000
# 8     20160718101500000
# 9     20160718102000000
# 10    20160718102500000
# 11    20160718103000000
# 12    20160718103500000
# 13    20160718104000000
# 14    20160718104500000
# 15    20160718105000000
# 16    20160718105500000
# 17    20160718110000000
# 18    20160718110500000
# 19    20160718111000000
# 20    20160718111500000
# 21    20160718112000000
# 22    20160718112500000
# 23    20160718113000000
# 24    20160718130500000
# 25    20160718131000000
# 26    20160718131500000
# 27    20160718132000000
# 28    20160718132500000
# 29    20160718133000000
# 30    20160718133500000
# 31    20160718134000000
# 32    20160718134500000
# 33    20160718135000000
# 34    20160718135500000
# 35    20160718140000000
# 36    20160718140500000
# 37    20160718141000000
# 38    20160718141500000
# 39    20160718142000000
# 40    20160718142500000
# 41    20160718143000000
# 42    20160718143500000
# 43    20160718144000000
# 44    20160718144500000
# 45    20160718145000000
# 46    20160718145500000
# 47    20160718150000000
# Name: time, dtype: object

# %%
index = pd.Index
index.data = data_5min['time']
plot_5min = data_5min['open'].plot(figsize=(12, 7))

# %%
index
# Out:
# pandas.core.indexes.base.Index

# %%
index.data
# Out:
# 0     20160718093500000
# 1     20160718094000000
# 2     20160718094500000
# 3     20160718095000000
# 4     20160718095500000
# 5     20160718100000000
# 6     20160718100500000
# 7     20160718101000000
# 8     20160718101500000
# 9     20160718102000000
# 10    20160718102500000
# 11    20160718103000000
# 12    20160718103500000
# 13    20160718104000000
# 14    20160718104500000
# 15    20160718105000000
# 16    20160718105500000
# 17    20160718110000000
# 18    20160718110500000
# 19    20160718111000000
# 20    20160718111500000
# 21    20160718112000000
# 22    20160718112500000
# 23    20160718113000000
# 24    20160718130500000
# 25    20160718131000000
# 26    20160718131500000
# 27    20160718132000000
# 28    20160718132500000
# 29    20160718133000000
# 30    20160718133500000
# 31    20160718134000000
# 32    20160718134500000
# 33    20160718135000000
# 34    20160718135500000
# 35    20160718140000000
# 36    20160718140500000
# 37    20160718141000000
# 38    20160718141500000
# 39    20160718142000000
# 40    20160718142500000
# 41    20160718143000000
# 42    20160718143500000
# 43    20160718144000000
# 44    20160718144500000
# 45    20160718145000000
# 46    20160718145500000
# 47    20160718150000000
# Name: time, dtype: object
